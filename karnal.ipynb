# %%
print("welcome to VIT BANK ATM")
restart="Y"
chances=3
balance=15000

while chances>=0:
    pin=int(input("please Enter Your 4 Digit Pin - "))
    if pin ==(1234):
        print("\n You have entered the correct Pin")
        
        
        while(restart not in('n','No','no,N')):
            print("\n Please press 1 for Your Balance \n")
            print("Please press 2 To make a withdrawal \n")
            print("Please press 3 To Deposit \n")
            print("Please press 4 to Exit \n")
            option=int(input("Enter Your option: "))
            
            
            
            if option ==1:
                print("Your balnce is ",balance)
                restart = input("\n Would you like to go back to the menu? ")
                if restart in ('n','NO','no,N'):
                    print("Thank You")
                    chances=-1
                    break
                    
                    
                    
            elif option == 2:
                option2=('y')
                withdrawal= float(input("How Much would you like to withdrawal? \n Available Notes- 100 200 500 2000 \n"))
                if( withdrawal%2000==0 or withdrawal%500==0 or withdrawal%200==0 or withdrawal%100==0):
                    balance= balance- withdrawal
                    print("You balance in account is ",balance)
                    restart = input("\n Would you like to go back to the menu? ")
                    if restart in ('n','NO','no,N'):
                        print("Thank You")
                        chances=-1
                        break
                else:
                    print("Invalid Amount!4, Please Retry")
                    restart= 'Y'
                    
                    
                    
            elif option ==3:
                deposit= float(input("How much would you Like to Deposite?"))
                balance = balance+ deposite
                print("Your balance is now ", balance)
                restart = input("\n Would you like to go back to the menu? ")
                if restart in ('n','No','no,N'):
                    print("Thank You")
                    chances=-1
                    break
                    
                    
                    
            elif option== 4:
                print("Thank You for using our ATM \n")
                chances=-1
                break
            else:
                print("Please Enter a correct no. \n")
                
                
                
    elif pin !=(1234):
        print("Incorrect Password")
        if chances==2:
            print("Last Try")
        chances= chances-1
        if chances == 0:
            print("NO more tries!")
            break
# Out:
# welcome to VIT BANK ATM
# please Enter Your 4 Digit Pin - 1234
#
#  You have entered the correct Pin
#
#  Please press 1 for Your Balance
#
# Please press 2 To make a withdrawal
#
# Please press 3 To Deposit
#
# Please press 4 to Exit
#
# Enter Your option: 2
# How Much would you like to withdrawal?
#  Available Notes- 100 200 500 2000
# 100
# You balance in account is  14900.0
